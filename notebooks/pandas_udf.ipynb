# %%
from pyspark.sql.functions import pandas_udf
from pyspark.sql.types import DoubleType
import pandas as pd

# %%
data = [
    (1, 10.0, 5.0),
    (2, 20.0, 3.5),
    (3, 30.0, 7.2)
]

df = spark.createDataFrame(data, ["id", "value1", "value2"])
df.show()

# %%
@pandas_udf(DoubleType())
def sum_values(v1: pd.Series, v2: pd.Series) -> pd.Series:
    return v1 + v2

# %%
result_df = df.withColumn("sum", sum_values(df["value1"], df["value2"]))
result_df.show()

# %% [markdown]
# ### Without defining udf, faster

# %%
display(df.withColumn("sum", df.value1 + df.value2).collect())

# %% [markdown]
# ### Installing newly created package with UDF

# %%
# Install from Workspace Files. If this path does not exist in Databricks,
# update it to the actual location of this project in your workspace.
# %pip install -e /Workspace/Users/piotrkuzmiak@op.pl/databricks/databricks_project
# %restart_python

# %% [markdown]
# ### Importing newly installed package

# %%
from databricks_sample_package.udfs.functions import is_valid_email

data_emails = [
    ("john.doe@example.com",),
    ("jane.smith@domain.com",),
    ("invalid.email.domain.com",),
    ("another.invalid.email.com",)
]

df_emails = spark.createDataFrame(data_emails, ["email"])
display(df_emails)
display(df_emails.withColumn("is_valid", is_valid_email(df_emails["email"])))

# %% [markdown]
# ### Testing the package

# %%
import databricks_sample_package
print(databricks_sample_package.__file__)

# %%
import subprocess
import databricks_sample_package

print("module:", databricks_sample_package)
print("__file__:", getattr(databricks_sample_package, "__file__", None))
print("__path__:", list(getattr(databricks_sample_package, "__path__", [])))
print("__spec__:", databricks_sample_package.__spec__)
subprocess.run(["python", "-m", "pip", "show", "databricks_sample_package"], check=False)
